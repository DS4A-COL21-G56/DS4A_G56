# %%
import pandas as pd
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from pandas.plotting import parallel_coordinates
import plotly.express as px

# %%
new_dataset = pd.read_csv('../data/processed/tidy_dataset.csv', ',', encoding='ISO-8859-1')

# %%
new_dataset
# Out:
#        Unnamed: 0  n_semesters  sum_credits       GPA  failed_subjects  \
# 0               0           11        150.0  3.504000                5
# 1               1            6        139.0  4.153237                1
# 2               2           10        141.0  4.078723                2
# 3               3           10        151.0  3.500000                7
# 4               4           10        139.0  4.069784                1
# ...           ...          ...          ...       ...              ...
# 10206       10206            1         17.0  4.288235                0
# 10207       10207            3         46.0  3.884783                0
# 10208       10208            3         30.0  3.786667                2
# 10209       10209            2         15.0  3.813333                1
# 10210       10210            1         20.0  3.560000                2
#
#                                                FACULTAD  \
# 0      FACULTAD DE CIENCIAS ADMINISTRATIVAS Y CONTABLES
# ...
